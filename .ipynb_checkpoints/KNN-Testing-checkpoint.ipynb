# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
df = pd.read_csv("features.csv")
df.head()
df = df.dropna()

# %%
heartWillGoOn = [{'acousticness': 0.732, 'danceability': 0.428, 'energy': 0.276,  
                 'id': '3oEHQmhvFLiE7ZYES0ulzv', 'instrumentalness': 5.33e-06, 'key': 4, 
                 'liveness': 0.117,'loudness': -11.729,'mode': 1,
                  'speechiness': 0.0312, 'tempo': 99.195, 'valence': 0.0382}]

# %%
df = df.append(heartWillGoOn)
df = df.reset_index()
df.tail()
# Out:
# C:\Users\alexb\Anaconda3\lib\site-packages\pandas\core\frame.py:5186: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   other = other.loc[:, self.columns]
# C:\Users\alexb\Anaconda3\lib\site-packages\pandas\core\indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#          index  Unnamed: 0  acousticness  danceability  energy  \
# 143674  143675    143675.0      0.000157         0.634   0.958
# 143675  143676    143676.0      0.082000         0.507   0.849
# 143676  143677    143677.0      0.000821         0.681   0.942
# 143677  143678    143678.0      0.033900         0.834   0.869
# 143678       0         NaN      0.732000         0.428   0.276
#
#                             id  instrumentalness  key  liveness  loudness  \
# 143674  4WYZ2dp1BhnPovdiXsvU2S          0.702000    9    0.0898    -5.501
# 143675  1biP5S4CFMNfLA0rceCmRF          0.000000    5    0.7970    -9.197
# 143676  3DZpiHNi3wQuoIMuiJ5jxJ          0.000030    9    0.0656    -4.475
# 143677  3MYe1siYBRujEK5fy9aa3h          0.000522    9    0.1460    -5.890
# 143678  3oEHQmhvFLiE7ZYES0ulzv          0.000005    4    0.1170   -11.729
#
#         mode  speechiness    tempo  valence
# 143674     0       0.0340  140.015   0.8140
# 143675     1       0.1040  132.953   0.1540
# 143676     1       0.0483  131.965   0.8850
# 143677     1       0.0280  113.889   0.7850
# 143678     1       0.0312   99.195   0.0382

# %%
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(df[['acousticness','danceability','energy','instrumentalness','key',\
                                           'liveness','loudness','mode','speechiness','tempo','valence']])
df_normalized = pd.DataFrame(np_scaled)

# %%
df_normalized.columns = ['acousticness','danceability','energy','instrumentalness','key',\
                                           'liveness','loudness','mode','speechiness','tempo','valence']

# %%
df_normalized['id'] = df['id']
df_normalized.tail()
# Out:
#         acousticness  danceability  energy  instrumentalness       key  \
# 143674      0.000158      0.640404   0.958          0.702000  0.818182
# 143675      0.082329      0.512121   0.849          0.000000  0.454545
# 143676      0.000824      0.687879   0.942          0.000030  0.818182
# 143677      0.034036      0.842424   0.869          0.000522  0.818182
# 143678      0.734940      0.432323   0.276          0.000005  0.363636
#
#         liveness  loudness  mode  speechiness     tempo  valence  \
# 143674  0.090070  0.858171   0.0     0.035088  0.560230   0.8140
# 143675  0.799398  0.799972   1.0     0.107327  0.531974   0.1540
# 143676  0.065797  0.874327   1.0     0.049845  0.528021   0.8850
# 143677  0.146439  0.852045   1.0     0.028896  0.455695   0.7850
# 143678  0.117352  0.760101   1.0     0.032198  0.396901   0.0382
#
#                             id
# 143674  4WYZ2dp1BhnPovdiXsvU2S
# 143675  1biP5S4CFMNfLA0rceCmRF
# 143676  3DZpiHNi3wQuoIMuiJ5jxJ
# 143677  3MYe1siYBRujEK5fy9aa3h
# 143678  3oEHQmhvFLiE7ZYES0ulzv

# %%
df_normalized,heartSong=df_normalized.drop(df_normalized.tail(1).index),df_normalized.tail(1)
heartSong
# Out:
#         acousticness  danceability  energy  instrumentalness       key  \
# 143678       0.73494      0.432323   0.276          0.000005  0.363636
#
#         liveness  loudness  mode  speechiness     tempo  valence  \
# 143678  0.117352  0.760101   1.0     0.032198  0.396901   0.0382
#
#                             id
# 143678  3oEHQmhvFLiE7ZYES0ulzv

# %%
heartSong['acousticness']
# Out:
# 143678    0.73494
# Name: acousticness, dtype: float64

# %%
df_normalized.tail()
# Out:
#         acousticness  danceability  energy  instrumentalness       key  \
# 143673      0.156627      0.780808   0.694          0.009980  0.454545
# 143674      0.000158      0.640404   0.958          0.702000  0.818182
# 143675      0.082329      0.512121   0.849          0.000000  0.454545
# 143676      0.000824      0.687879   0.942          0.000030  0.818182
# 143677      0.034036      0.842424   0.869          0.000522  0.818182
#
#         liveness  loudness  mode  speechiness     tempo  valence  \
# 143673  0.094082  0.839464   0.0     0.032508  0.380192    0.829
# 143674  0.090070  0.858171   0.0     0.035088  0.560230    0.814
# 143675  0.799398  0.799972   1.0     0.107327  0.531974    0.154
# 143676  0.065797  0.874327   1.0     0.049845  0.528021    0.885
# 143677  0.146439  0.852045   1.0     0.028896  0.455695    0.785
#
#                             id
# 143673  3fBzXNIRUnHl80OFhB0jo7
# 143674  4WYZ2dp1BhnPovdiXsvU2S
# 143675  1biP5S4CFMNfLA0rceCmRF
# 143676  3DZpiHNi3wQuoIMuiJ5jxJ
# 143677  3MYe1siYBRujEK5fy9aa3h

# %%
df_normalized['score'] = df_normalized['acousticness'].apply(lambda row: np.abs(row-heartSong['acousticness'])) + \
    df_normalized['danceability'].apply(lambda row: np.abs(row-heartSong['danceability'])) + \
    df_normalized['energy'].apply(lambda row: np.abs(row-heartSong['energy'])) + \
    df_normalized['instrumentalness'].apply(lambda row: np.abs(row-heartSong['instrumentalness'])) + \
    df_normalized['key'].apply(lambda row: np.abs(row-heartSong['key'])) + \
    df_normalized['liveness'].apply(lambda row: np.abs(row-heartSong['liveness'])) + \
    df_normalized['loudness'].apply(lambda row: np.abs(row-heartSong['loudness'])) + \
    df_normalized['mode'].apply(lambda row: np.abs(row-heartSong['mode'])) + \
    df_normalized['speechiness'].apply(lambda row: np.abs(row-heartSong['speechiness'])) + \
    df_normalized['tempo'].apply(lambda row: np.abs(row-heartSong['tempo'])) + \
    df_normalized['valence'].apply(lambda row: np.abs(row-heartSong['valence']))

# %%
df_normalized['score'].min()
# Out:
# 0.2176435802386169

# %%
df_normalized['class'] = df_normalized['score'].apply(lambda row: True if row < 1 else False)
df_normalized.head(10)
# Out:
#    acousticness  danceability  energy  instrumentalness       key  liveness  \
# 0      0.573293      0.647475   0.665          0.001070  0.636364  0.159478
# 1      0.720884      0.679798   0.405          0.000268  0.636364  0.122367
# 2      0.247992      0.732323   0.488          0.000000  0.636364  0.080341
# 3      0.516064      0.691919   0.503          0.000028  1.000000  0.082447
# 4      0.790161      0.614141   0.331          0.000000  0.636364  0.324975
# 5      0.591365      0.716162   0.692          0.000000  0.000000  0.058275
# 6      0.918675      0.551515   0.293          0.000000  0.636364  0.166499
# 7      0.653614      0.760606   0.550          0.000000  0.000000  0.153460
# 8      0.275100      0.666667   0.508          0.000000  0.545455  0.121364
# 9      0.027912      0.714141   0.679          0.000000  0.454545  0.102307
#
#    loudness  mode  speechiness     tempo  valence                      id  \
# 0  0.821355   1.0     0.027141  0.552236    0.677  1vPk6ZTflnvm8LgtXzPDrT
# 1  0.797988   1.0     0.032301  0.624026    0.652  6OpIhef0IbK0tkEU2m9c4T
# 2  0.792114   1.0     0.034675  0.496523    0.456  36qxb23eWvnQiJWEMgWYO6
# 3  0.831827   1.0     0.042931  0.375806    0.807  1FIlg68WTgn0xGL8vPy5Rj
# 4  0.776431   1.0     0.029928  0.552692    0.709  7oBAMX1mPa2qiqmSunLirZ
# 5  0.823749   1.0     0.024871  0.400146    0.927  0gXysVSXeGvRwEhcdKKDll
# 6  0.772872   1.0     0.028070  0.588875    0.223  29cZPOOZ6uH6ipBhneNGwQ
# 7  0.820348   1.0     0.031476  0.452209    0.663  5N0akr3xBzThgPYK7JMa7z
# 8  0.813026   1.0     0.029205  0.324247    0.560  2wvHCpDbeA5iDHVNAOxb3A
# 9  0.826347   0.0     0.184727  0.504317    0.686  35lyqJMy8RQL7XNeFxdWiO
#
#       score  class
# 0  1.942162  False
# 1  1.547450  False
# 2  1.860603  False
# 3  2.249115  False
# 4  1.617585  False
# 5  2.229151  False
# 6  1.035480  False
# 7  1.824436  False
# 8  1.762389  False
# 9  3.471797  False

# %%
df_normalized['class'].value_counts()
# Out:
# False    140080
# True       3598
# Name: class, dtype: int64

# %%
target = df_normalized["class"]
target_names = ["Not Recommended", "Recommended"]

# %%
data = df_normalized.drop(["class", "score","id"], axis=1)
feature_names = data.columns
data.head()
# Out:
#    acousticness  danceability  energy  instrumentalness       key  liveness  \
# 0      0.573293      0.647475   0.665          0.001070  0.636364  0.159478
# 1      0.720884      0.679798   0.405          0.000268  0.636364  0.122367
# 2      0.247992      0.732323   0.488          0.000000  0.636364  0.080341
# 3      0.516064      0.691919   0.503          0.000028  1.000000  0.082447
# 4      0.790161      0.614141   0.331          0.000000  0.636364  0.324975
#
#    loudness  mode  speechiness     tempo  valence
# 0  0.821355   1.0     0.027141  0.552236    0.677
# 1  0.797988   1.0     0.032301  0.624026    0.652
# 2  0.792114   1.0     0.034675  0.496523    0.456
# 3  0.831827   1.0     0.042931  0.375806    0.807
# 4  0.776431   1.0     0.029928  0.552692    0.709

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=72)

# %%
# Loop through different k values to see which has the highest accuracy
# Note: We only use odd numbers because we don't want any ties
train_scores = []
test_scores = []
for k in range(1, 16, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train_score = knn.score(X_train, y_train)
    test_score = knn.score(X_test, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 16, 2), train_scores, marker='o')
plt.plot(range(1, 16, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.savefig("static/images/knn.png")
plt.show()
# Out:
# k: 1, Train/Test Score: 1.000/0.991
# k: 3, Train/Test Score: 0.996/0.992
# k: 5, Train/Test Score: 0.996/0.993
# k: 7, Train/Test Score: 0.995/0.993
# k: 9, Train/Test Score: 0.995/0.993
# k: 11, Train/Test Score: 0.995/0.993
# k: 13, Train/Test Score: 0.995/0.993
# k: 15, Train/Test Score: 0.994/0.993

# %%
# Note that k: 13 seems to be the best choice for this dataset
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train, y_train)
print('k=7 Test Acc: %.3f' % knn.score(X_test, y_test))
# Out:
# k=7 Test Acc: 0.993

# %%
from sklearn.externals import joblib
knn_filename = 'Saved Models/knn.sav'
joblib.dump(knn, knn_filename)
# Out:
# ['Saved Models/knn.sav']

# %%
loaded_model = joblib.load(knn_filename)
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# 0.9931236080178174

# %%
test = knn.predict_proba(X_test)
print(len(test))
# Out:
# 35920

# %%
import random
rand_list = []

for index, item in enumerate(test):
#     print(index, item)
    if item[0] == 1:
        rand_list.append({"id":index,
                         "score": item[0]})
        
rand_sel = random.sample(rand_list, 3)

# %%
# Grab three songs to load into 
for i in rand_sel:
    index = i["id"]
    print(df_normalized.loc[index]["id"])
# Out:
# 0w5u7wCW5rJDp9QHaWvSVX
# 5AnQZGp7osdjCVLeVb77fn
# 3wOMpzLSoLKFPccK8zI9i3

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)
from sklearn.svm import SVC 
svc = SVC(kernel='linear')
svc.fit(X_train, y_train)
print('Test Acc: %.3f' % svc.score(X_test, y_test))
from sklearn.metrics import classification_report
predictions = svc.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))
							
scores = svc.decision_function(df_normalized[['acousticness','danceability','energy','instrumentalness','key',\
                                           'liveness','loudness','mode','speechiness','tempo','valence']])
										   
df_normalized['predict'] = scores
print(df_normalized[df_normalized['predict'] > 1 ])
# Out:
# Test Acc: 0.975
#                  precision    recall  f1-score   support
#
# Not Recommended       0.98      1.00      0.99     35033
#     Recommended       0.00      0.00      0.00       887
#
#     avg / total       0.95      0.98      0.96     35920
#
# Empty DataFrame
# Columns: [acousticness, danceability, energy, instrumentalness, key, liveness, loudness, mode, speechiness, tempo, valence, id, score, class, predict]
# Index: []

# %%
svc_filname = 'Saved Models/svc.sav'
joblib.dump(knn, svc_filname)
# Out:
# ['Saved Models/svc.sav']
